# %%
library(glue)
library(tidyr)
library(dplyr)
library(scales)
library(ggplot2)
library(ggthemes)
library(tidyverse)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:glue’:
#
#     collapse
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ tibble  3.0.6     ✔ purrr   0.3.4
# ✔ readr   1.3.1     ✔ stringr 1.4.0
# ✔ tibble  3.0.6     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ readr::col_factor() masks scales::col_factor()
# ✖ dplyr::collapse()   masks glue::collapse()
# ✖ purrr::discard()    masks scales::discard()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::lag()        masks stats::lag()

# %%
usa_names <- read_csv("usa_1910_current.csv",
                      col_types=cols(state = col_character(),
                                      gender = col_character(),
                                      year = col_double(),
                                      name = col_character(),
                                      number = col_double()
                                    )) %>%
               mutate(gender=case_when(gender=='M' ~ "Male",
                                       gender=='F' ~ "Female",
                                       TRUE ~ "Other"))
head(usa_names)
# Out:
#   state gender year name     number
# 1 MI    Female 1910 Helen    368
# 2 MI    Female 1910 Mary     349
# 3 MI    Female 1910 Margaret 272
# 4 MI    Female 1910 Dorothy  265
# 5 MI    Female 1910 Ruth     212
# 6 MI    Female 1910 Florence 164

# %%
top10_most_popular_names <- usa_names %>%
  group_by(gender, name) %>%
  summarize(count=sum(number, na.rm=TRUE)) %>%
  collect() %>%
  arrange(desc(count), `.by_group` = TRUE) %>%
  mutate(rank=row_number()) %>%
  filter(rank <= 10)

head(top10_most_popular_names, 20)
# Out:
# `summarise()` has grouped output by 'gender'. You can override using the `.groups` argument.
#    gender name      count   rank
# 1  Female Mary      3743561  1
# 2  Female Patricia  1569296  2
# 3  Female Elizabeth 1545720  3
# 4  Female Jennifer  1466943  4
# 5  Female Linda     1448280  5
# 6  Female Barbara   1424504  6
# 7  Female Margaret  1133157  7
# 8  Female Susan     1109542  8
# 9  Female Dorothy   1053909  9
# 10 Female Jessica   1044437 10
# 11 Male   James     5010765  1
# 12 Male   John      4878703  2
# 13 Male   Robert    4739061  3
# 14 Male   Michael   4360172  4
# 15 Male   William   3904738  5
# 16 Male   David     3606952  6
# 17 Male   Richard   2541959  7
# 18 Male   Joseph    2532162  8
# 19 Male   Charles   2279589  9
# 20 Male   Thomas    2251875 10

# %%
ds_start_year <- min(usa_names$year, na.rm=TRUE)
ds_end_year <- max(usa_names$year, na.rm=TRUE)

print(glue("ds_start_year={ds_start_year}, ds_end_year={ds_end_year}"))
# Out:
# ds_start_year=1910, ds_end_year=2019

# %%
options(repr.plot.width=20, repr.plot.height=8)

title <- "Top 10 most popular names of all times in the USA"
subtitle <- glue("Dataset timespan: {ds_start_year} to {ds_end_year} ")
caption <- "Source: bigquery-public-data.usa_names.usa_1910_current"
top10_most_popular_names %>%
  ggplot(aes(x=reorder(name, -count), y=count, col=gender, fill=gender)) + 
  geom_bar(stat='identity') +
  facet_wrap(~gender, scales="free") +
  scale_y_continuous(labels = comma) +
  theme_fivethirtyeight() +
  scale_color_tableau() +
  scale_fill_tableau() +
  coord_flip() +
  labs(title=title,
       subtitle=subtitle,
        caption=caption) +
  theme(legend.position="none") +
  theme(text = element_text(size=15)) +
  theme(axis.title = element_text()) +
  ylab("Number of occurrences of the name") + xlab("")
# Out:
# plot without title

# %%
# most popular names of the 2010s
most_popular_name_of_the_2010_decade <- usa_names %>%
  filter(year>=2010 & year<=2019) %>%
  group_by(gender, name) %>%
  summarize(count=sum(number, na.rm=TRUE)) %>%
  arrange(desc(count), `.by_group` = TRUE) %>%
  mutate(rank=row_number()) %>%
  filter(rank <= 10)

head(most_popular_name_of_the_2010_decade)
# Out:
# `summarise()` has grouped output by 'gender'. You can override using the `.groups` argument.
#   gender name     count  rank
# 1 Female Emma     194667 1
# 2 Female Olivia   184192 2
# 3 Female Sophia   180832 3
# 4 Female Isabella 170185 4
# 5 Female Ava      155546 5
# 6 Female Mia      128824 6

# %%
usa_names %>%
  #filter(name %in% c(top10_most_popular_names$name, most_popular_name_of_the_2010_decade$name)) %>%
  #filter(name %in% c(top10_most_popular_names$name)) %>%
  filter(name %in% c(most_popular_name_of_the_2010_decade$name)) %>%
  #filter(name %in% most_popular_name_of_the_2010_decade$name) %>%
  group_by(year, gender, name) %>%
  summarize(count=sum(number)) %>%
  ggplot(aes(x=year, y=count, col=name)) +
  geom_line() + 
  facet_wrap(~gender, scales="free") +
  scale_y_continuous(labels = comma) +
  theme_fivethirtyeight() +
  scale_color_tableau(palette="Tableau 20") +
  scale_fill_tableau(palette="Tableau 20") +
  labs(title=title,
       subtitle=subtitle,
        caption=caption) +
  theme(legend.position="bottom") +
  theme(text = element_text(size=15)) +
  theme(axis.title = element_text()) +
  ylab("Number of occurrences of the name") + xlab("")
# Out:
# `summarise()` has grouped output by 'year', 'gender'. You can override using the `.groups` argument.
# plot without title

# %%
usa_names %>%
  filter(year >=2010) %>%
  group_by(year, name) %>%
  summarize(count = sum(number)) %>%
  ungroup() %>%
  arrange(desc(year)) %>%
  group_by(name) %>%
  mutate(diff_from_prev = count-lag(count)) %>%
  filter(!is.na(diff_from_prev)) %>%
  ungroup() %>%
  group_by(name) %>%
  summarize(trend = sum(diff_from_prev)) %>%
  arrange(desc(trend))
# Out:
# `summarise()` has grouped output by 'year'. You can override using the `.groups` argument.
#       name        trend
# 1     Jacob       11462
# 2     Jayden      10609
# 3     Isabella     9615
# 4     Joshua       8874
# 5     Alexis       7946
# 6     Anthony      7844
# 7     Tyler        7511
# 8     Andrew       7498
# 9     Christopher  7323
# 10    Sophia       6932
# 11    Madison      6917
# 12    Michael      6845
# 13    Ethan        6763
# 14    Gavin        6624
# 15    Aiden        6259
# 16    Emily        6063
# 17    Addison      5966
# 18    Brandon      5884
# 19    Evan         5798
# 20    Jonathan     5720
# 21    Ryan         5566
# 22    Alexander    5532
# 23    Christian    5470
# 24    Brayden      5462
# 25    Chloe        5396
# 26    Daniel       5348
# 27    Justin       5346
# 28    Nathan       5336
# 29    Alyssa       5334
# 30    David        5307
# ⋮     ⋮           ⋮
# 12917 Willow      -3461
# 12918 Sebastian   -3473
# 12919 Camila      -3508
# 12920 Hudson      -3656
# 12921 Emilia      -3860
# 12922 Nora        -3968
# 12923 Asher       -4157
# 12924 Hazel       -4216
# 12925 Henry       -4305
# 12926 Nova        -4308
# 12927 Eleanor     -4331
# 12928 Scarlett    -4336
# 12929 Evelyn      -4552
# 12930 Everly      -4660
# 12931 Grayson     -4841
# 12932 Penelope    -5165
# 12933 Ezra        -5264
# 12934 Maverick    -5288
# 12935 Leo         -5521
# 12936 Lincoln     -5687
# 12937 Aria        -6191
# 12938 Mila        -6461
# 12939 Theodore    -6530
# 12940 Luna        -6843
# 12941 Mateo       -7357
# 12942 Amelia      -7403
# 12943 Harper      -7640
# 12944 Charlotte   -7784
# 12945 Oliver      -9227
# 12946 Liam        -9574

# %%
usa_names %>%
  #filter(name %in% c(top10_most_popular_names$name, most_popular_name_of_the_2010_decade$name)) %>%
  #filter(name %in% c(top10_most_popular_names$name)) %>%
  filter(name %in% c("Liam", "Oliver", "Charlotte", "Amelia")) %>%
  #filter(name %in% most_popular_name_of_the_2010_decade$name) %>%
  group_by(year, gender, name) %>%
  summarize(count=sum(number)) %>%
  ggplot(aes(x=year, y=count, col=name)) +
  geom_line() + 
  facet_wrap(~gender, scales="free") +
  scale_y_continuous(labels = comma) +
  theme_fivethirtyeight() +
  scale_color_tableau(palette="Tableau 20") +
  scale_fill_tableau(palette="Tableau 20") +
  labs(title=title,
       subtitle=subtitle,
        caption=caption) +
  theme(legend.position="bottom") +
  theme(text = element_text(size=15)) +
  theme(axis.title = element_text()) +
  ylab("Number of occurrences of the name") + xlab("")
# Out:
# `summarise()` has grouped output by 'year', 'gender'. You can override using the `.groups` argument.
# plot without title
